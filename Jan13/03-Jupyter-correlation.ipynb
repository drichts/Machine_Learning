# %% [markdown]
# # imporrt what you need

# %%
# %matplotlib inline
import pandas as pd
import os
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix    
print('Done!')
# Out:
# Done!

# %% [markdown]
# # load you data

# %%
Your_Data= pd.read_csv('Height_Weight.csv')
print('Done!')
# Out:
# Done!

# %% [markdown]
# # get the name of the parameters and the data type

# %%
Your_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   25000 non-null  int64
#  1   Height  25000 non-null  float64
#  2   Weight  25000 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 586.1 KB

# %% [markdown]
# # find the correlation btween all the parameters

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # find corrolation between all the features

# %%
Your_Data.corr()
# Out:
#            Index    Height    Weight
# Index   1.000000  0.009626 -0.007257
# Height  0.009626  1.000000  0.502859
# Weight -0.007257  0.502859  1.000000

# %% [markdown]
# # Find the correlation between two selected parameters

# %%
Your_Data[["Height","Weight"]].corr()
# Out:
#           Height    Weight
# Height  1.000000  0.502859
# Weight  0.502859  1.000000

# %% [markdown]
# # get the value of a selected parameter as a variable

# %%
Height=Your_Data["Height"].values
Weight=Your_Data["Weight"].values

# %% [markdown]
# # plot Weight vs. Height using  '.'

# %%
plt.plot(Height,Weight, '.')

# %% [markdown]
# # make the plot more informative by adding labels, title , … And save it with a name

# %%
plt.plot(Height,Weight, '.')
plt.title('Correlation', fontsize=19)
plt.xlabel('Height')
plt.ylabel('Weight')

fig_name='fig-correlation'  # choose a name for you plot to save '
plt.savefig(fig_name+'.png', format='png', dpi=100)

# %% [markdown]
# # Plot a one-to-one line in the plot.

# %%
plt.plot(Height,Weight, '.')
plt.title('Correlation', fontsize=19)
plt.xlabel('Height', fontsize=15)
plt.ylabel('Weight', fontsize=15)
plt.plot([60,160],[60,160],'-r')

# %% [markdown]
# # Conariance
# ![image.png](attachment:image.png)

# %%
Your_Data.cov(min_periods=None, ddof=1)
# Out:
#                Index      Height      Weight
# Index   5.208542e+07  132.106201 -610.728548
# Height  1.321062e+02    3.616382   11.151029
# Weight -6.107285e+02   11.151029  135.976532
